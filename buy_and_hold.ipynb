# %%
# !rqlalpha
# Out:
# /bin/sh: 1: rqlalpha: not found

# %%
# !rqalpha
# Out:
# Usage: rqalpha [OPTIONS] COMMAND [ARGS]...
#
# Options:
#   -v, --verbose
#   -h, --help     Show this message and exit.
#
# Commands:
#   examples         Generate example strategies to target folder
#   generate_config  Generate default config file
#   mod              Mod management command rqalpha mod list...
#   plot             [sys_analyser] draw result DataFrame
#   report           [sys_analyser] Generate report from backtest...
#   run              Start to run a strategy
#   update_bundle    Sync Data Bundle
#   version          Output Version Info

# %%
# !rqalpha version
# Out:
# Current Version:  (3, 1, 1)

# %%
# !rqalpha update_bundle -d ./data
# Out:
# 尝试 http://7xjci3.com1.z0.glb.clouddn.com/bundles_v3/rqbundle_20180821.tar.bz2 ...
# 尝试 http://7xjci3.com1.z0.glb.clouddn.com/bundles_v3/rqbundle_20180820.tar.bz2 ...
# 下载中 ...  [####################################]  100%
# 数据下载成功: /home/aadebuger/Documents/cloud2018/rqalphalr/data/bundle

# %%
# !rqalpha run -f ./buy_and_hold.py -d ./data -s 2016-06-01 -e 2016-12-01 --account stock 100000 --benchmark 000300.XSHG
# Out:
# Traceback (most recent call last):
#   File "/home/aadebuger/rqalphaenv/lib/python3.5/site-packages/rqalpha/main.py", line 202, in run
#     env.set_data_source(BaseDataSource(config.base.data_bundle_path))
#   File "/home/aadebuger/rqalphaenv/lib/python3.5/site-packages/rqalpha/data/base_data_source.py", line 50, in __init__
#     DayBarStore(_p('stocks.bcolz'), StockBarConverter),
#   File "/home/aadebuger/rqalphaenv/lib/python3.5/site-packages/rqalpha/data/daybar_store.py", line 26, in __init__
#     self._table = bcolz.open(main, 'r')
#   File "/home/aadebuger/rqalphaenv/lib/python3.5/site-packages/bcolz/toplevel.py", line 140, in open
#     return bcolz.carray(rootdir=rootdir, mode=mode)
#   File "bcolz/carray_ext.pyx", line 1067, in bcolz.carray_ext.carray.__cinit__
#   File "bcolz/carray_ext.pyx", line 1369, in bcolz.carray_ext.carray._read_meta
# FileNotFoundError: [Errno 2] No such file or directory: './data/stocks.bcolz/meta/sizes'
# ...

# %%
# !rqalpha run -f ./buy_and_hold.py -s 2016-06-01 -e 2016-12-01 --account stock 100000 --benchmark 000300.XSHG
# Out:
# 2016-06-01 INFO init
# 2016-06-01 INFO Before Trading
# 2016-06-01 INFO handle_bar
# 2016-06-02 INFO Before Trading
# 2016-06-02 INFO handle_bar
# 2016-06-03 INFO Before Trading
# 2016-06-03 INFO handle_bar
# 2016-06-06 INFO Before Trading
# 2016-06-06 INFO handle_bar
# 2016-06-07 INFO Before Trading
# 2016-06-07 INFO handle_bar
# 2016-06-08 INFO Before Trading
# 2016-06-08 INFO handle_bar
# 2016-06-13 INFO Before Trading
# 2016-06-13 INFO handle_bar
# 2016-06-14 INFO Before Trading
# 2016-06-14 INFO handle_bar
# 2016-06-15 INFO Before Trading
# 2016-06-15 INFO handle_bar
# 2016-06-16 INFO Before Trading
# 2016-06-16 INFO handle_bar
# 2016-06-17 INFO Before Trading
# 2016-06-17 INFO handle_bar
# 2016-06-20 INFO Before Trading
# 2016-06-20 INFO handle_bar
# 2016-06-21 INFO Before Trading
# 2016-06-21 INFO handle_bar
# 2016-06-22 INFO Before Trading
# 2016-06-22 INFO handle_bar
# 2016-06-23 INFO Before Trading
# 2016-06-23 INFO handle_bar
# 2016-06-24 INFO Before Trading
# ...
