# %%
# !rqalpha update_bundle
# Out:
# 尝试 http://7xjci3.com1.z0.glb.clouddn.com/bundles_v3/rqbundle_20180821.tar.bz2 ...
# 尝试 http://7xjci3.com1.z0.glb.clouddn.com/bundles_v3/rqbundle_20180820.tar.bz2 ...
# 下载中 ...  [####################################]  100%
# 数据下载成功: /home/aadebuger/.rqalpha/bundle

# %%
# !rqalpha examples -d ./

# %%
# !ls
# Out:
# buy_and_hold.ipynb  buy_and_hold.py  data  examples  Untitled.ipynb

# %%
# !rqalpha run -f ./examples/rsi.py -s 2014-01-01 -e 2016-01-01 -o result.pkl --plot --progress --account stock 100000
# Out:
# 2014-01-02 INFO target available cash caled: 30000.0
#   [------------------------------------]    0%2014-01-03 INFO target available cash caled: 21066.659040000002
# 2014-01-06 INFO target available cash caled: 14764.02096
# 2014-01-07 INFO target available cash caled: 10358.2992
# 2014-01-08 INFO target available cash caled: 7256.21952
#   [------------------------------------]    1%2014-01-09 INFO target available cash caled: 5146.132799999999
# 2014-01-10 INFO target available cash caled: 3644.6327999999994
# 2014-01-13 INFO target available cash caled: 2597.332799999999
# 2014-01-14 INFO target available cash caled: 1839.8327999999995
# 2014-01-15 INFO target available cash caled: 1311.2327999999993
#   [------------------------------------]    2%2014-01-16 INFO target available cash caled: 933.2327999999993
# 2014-01-17 INFO target available cash caled: 706.7327999999994
# 2014-01-20 INFO target available cash caled: 556.4327999999994
# ...

# %%
# !rqalpha run -f ./examples/rsi.py -s 2014-01-01 -e 2016-01-01 -o result.pkl --plot --progress --account stock 100000 -o result.pkl
# Out:
# 2014-01-02 INFO target available cash caled: 30000.0
#   [------------------------------------]    0%2014-01-03 INFO target available cash caled: 21066.659040000002
# 2014-01-06 INFO target available cash caled: 14764.02096
# 2014-01-07 INFO target available cash caled: 10358.2992
# 2014-01-08 INFO target available cash caled: 7256.21952
#   [------------------------------------]    1%2014-01-09 INFO target available cash caled: 5146.132799999999
# 2014-01-10 INFO target available cash caled: 3644.6327999999994
# 2014-01-13 INFO target available cash caled: 2597.332799999999
# 2014-01-14 INFO target available cash caled: 1839.8327999999995
# 2014-01-15 INFO target available cash caled: 1311.2327999999993
#   [------------------------------------]    2%2014-01-16 INFO target available cash caled: 933.2327999999993
# 2014-01-17 INFO target available cash caled: 706.7327999999994
# 2014-01-20 INFO target available cash caled: 556.4327999999994
# ...

# %%
# !ls
# Out:
# buy_and_hold.ipynb  buy_and_hold.py  data  examples  result.pkl  rsi.ipynb

# %%
import pandas as pd

result_dict = pd.read_pickle('result.pkl')

result_dict.keys()
# Out:
# dict_keys(['summary', 'stock_positions', 'stock_account', 'portfolio', 'trades'])

# %%
# !rqalpha run -f ./examples/rsi.py -s 2014-01-01 -e 2016-01-01 -o result.pkl --plot --progress --account stock 100000 --plot -o result.pkl
# Out:
# 2014-01-02 INFO target available cash caled: 30000.0
#   [------------------------------------]    0%2014-01-03 INFO target available cash caled: 21066.659040000002
# 2014-01-06 INFO target available cash caled: 14764.02096
# 2014-01-07 INFO target available cash caled: 10358.2992
# 2014-01-08 INFO target available cash caled: 7256.21952
#   [------------------------------------]    1%2014-01-09 INFO target available cash caled: 5146.132799999999
# 2014-01-10 INFO target available cash caled: 3644.6327999999994
# 2014-01-13 INFO target available cash caled: 2597.332799999999
# 2014-01-14 INFO target available cash caled: 1839.8327999999995
# 2014-01-15 INFO target available cash caled: 1311.2327999999993
#   [------------------------------------]    2%2014-01-16 INFO target available cash caled: 933.2327999999993
# 2014-01-17 INFO target available cash caled: 706.7327999999994
# 2014-01-20 INFO target available cash caled: 556.4327999999994
# ...

# %%
# %load_ext rqalpha

# %%
# %%rqalpha -h
# Out:
# UsageError: %%rqalpha is a cell magic, but the cell body is empty. Did you mean the line magic %rqalpha (single %)?

# %%
# %rqalpha (single %)?
# Out:
# Usage: ipykernel_launcher.py [OPTIONS]
#
# Error: Got unexpected extra arguments ((single %)?)

# %%
# !rqalpha run -f ./examples/rsi.py  -d ./data/bundle/ -s 2014-01-01 -e 2016-01-01 -o result.pkl --plot --progress --account stock 100000 --plot -o result.pkl
# Out:
# 2014-01-02 INFO target available cash caled: 30000.0
#   [------------------------------------]    0%2014-01-03 INFO target available cash caled: 21066.659040000002
# 2014-01-06 INFO target available cash caled: 14764.02096
# 2014-01-07 INFO target available cash caled: 10358.2992
# 2014-01-08 INFO target available cash caled: 7256.21952
#   [------------------------------------]    1%2014-01-09 INFO target available cash caled: 5146.132799999999
# 2014-01-10 INFO target available cash caled: 3644.6327999999994
# 2014-01-13 INFO target available cash caled: 2597.332799999999
# 2014-01-14 INFO target available cash caled: 1839.8327999999995
# 2014-01-15 INFO target available cash caled: 1311.2327999999993
#   [------------------------------------]    2%2014-01-16 INFO target available cash caled: 933.2327999999993
# 2014-01-17 INFO target available cash caled: 706.7327999999994
# 2014-01-20 INFO target available cash caled: 556.4327999999994
# ...
